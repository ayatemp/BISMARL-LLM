# %%
print("hello")
# Out:
# hello

# %%
# MODEL_DIR = "./irm_deberta_unc_iso"
MODEL_DIR = "ayarnte/IRM_high_ver"

# %%
import sys, subprocess
print("PY:", sys.executable)
subprocess.check_call([sys.executable, "-m", "pip", "install", "-U",
                       "accelerate>=1.11.0", "peft==0.17.1", "transformers>=4.57.1"])
# Out:
# PY: /app/.venv/bin/python
# Requirement already satisfied: accelerate>=1.11.0 in /app/.venv/lib/python3.12/site-packages (1.11.0)
# Requirement already satisfied: peft==0.17.1 in /app/.venv/lib/python3.12/site-packages (0.17.1)
# Requirement already satisfied: transformers>=4.57.1 in /app/.venv/lib/python3.12/site-packages (4.57.1)
# Requirement already satisfied: numpy>=1.17 in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (25.0)
# Requirement already satisfied: psutil in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (6.0.0)
# Requirement already satisfied: pyyaml in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (2.8.0+cu128)
# Requirement already satisfied: tqdm in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (4.66.4)
# Requirement already satisfied: safetensors in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (0.4.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /app/.venv/lib/python3.12/site-packages (from peft==0.17.1) (0.34.4)
# Requirement already satisfied: filelock in /app/.venv/lib/python3.12/site-packages (from transformers>=4.57.1) (3.20.0)
# Requirement already satisfied: regex!=2019.12.17 in /app/.venv/lib/python3.12/site-packages (from transformers>=4.57.1) (2024.5.15)
# Requirement already satisfied: requests in /app/.venv/lib/python3.12/site-packages (from transformers>=4.57.1) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /app/.venv/lib/python3.12/site-packages (from transformers>=4.57.1) (0.22.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /app/.venv/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft==0.17.1) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /app/.venv/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft==0.17.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /app/.venv/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft==0.17.1) (1.2.0)
# Requirement already satisfied: setuptools in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (1.14.0)
# Requirement already satisfied: networkx in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (3.5)
# Requirement already satisfied: jinja2 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /app/.venv/lib/python3.12/site-packages (from torch>=1.13.0->peft==0.17.1) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /app/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft==0.17.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /app/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->peft==0.17.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /app/.venv/lib/python3.12/site-packages (from requests->transformers>=4.57.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /app/.venv/lib/python3.12/site-packages (from requests->transformers>=4.57.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /app/.venv/lib/python3.12/site-packages (from requests->transformers>=4.57.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /app/.venv/lib/python3.12/site-packages (from requests->transformers>=4.57.1) (2025.10.5)
# 0

# %%
import torch, transformers, accelerate, peft
print("torch:", torch.__version__)
print("transformers:", transformers.__version__)
print("accelerate:", accelerate.__version__)
print("peft:", peft.__version__)
# Out:
# torch: 2.8.0+cu128
# transformers: 4.57.1
# accelerate: 1.11.0
# peft: 0.17.1

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # これを一番最初に

# %%
from huggingface_hub import login
login("<REDACTED>")  # あなたの読み取り権限付きトークン

from transformers import AutoTokenizer, AutoModelForSequenceClassification

auth = {"token": True}  # 直前の login を使う
tok = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, **auth)
mdl = AutoModelForSequenceClassification.from_pretrained(MODEL_DIR, use_safetensors=True, **auth)

# %%
from irm_infer_only import IRMScorer

# ★ここだけ変更：ローカルフォルダ → HFのrepo_id

MAX_LEN = 512
STRIDE_RATIO = 0.5

scorer = IRMScorer(
    model_dir=MODEL_DIR,            # ← HF上のモデルを直接読む
    max_length=MAX_LEN,
    window_stride_ratio=STRIDE_RATIO,
)

title = "A differentiable bisociation module for cross-domain idea generation"
body  = """We propose a simple yet effective module that encourages cross-domain association 
during idea generation. The model learns to connect distant concepts by optimizing a 
rank-augmented reward signal derived from peer-review score predictors..."""

res = scorer.score_ideas([title], [body])  # [{'raw_score': ..., 'reward': ...}]
print(res[0])
# Out:
# You're using a DebertaV2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'raw_score': -0.08675764501094818, 'reward': 0.0, 'uncertainty': 0.7913018804374616}

# %%
import pandas as pd

titles = [
    "Self-supervised curation of literature for proposal writing",
    "Neural reviewer: modeling rebuttal sensitivity in peer-review",
    "Spectral reward shaping for creative large language models",
]
bodies = [
    "We introduce an automatic pipeline that mines and clusters prior work to help formulate new proposals...",
    "We study how rebuttal content shifts reviewer scoring and propose a model that predicts post-rebuttal changes...",
    "We shape the reward landscape using spectral properties of idea graphs to promote non-trivial associations...",
]

outs = scorer.score_ideas(titles, bodies)

df = pd.DataFrame([{
    "title": t,
    "raw_score": o["raw_score"],
    "reward_0_1": o["reward"],
} for t, o in zip(titles, outs)])

df.sort_values("reward_0_1", ascending=False).reset_index(drop=True)
# Out:
#                                                title  raw_score  reward_0_1
# 0  Self-supervised curation of literature for pro...  -0.667432         0.0
# 1  Neural reviewer: modeling rebuttal sensitivity...   0.112594         0.0
# 2  Spectral reward shaping for creative large lan...  -0.238549         0.0

# %%
from datasets import load_dataset

ds = load_dataset("ayarnte/iclr25")
df_fromInternet = ds["train"].to_pandas()

df_fromInternet.head()
# Out:
#    year         id                                              title  \
# 0  2017  B1-Hhnslg        Prototypical Networks for Few-shot Learning
# 1  2017  B1-q5Pqxl  Machine Comprehension Using Match-LSTM and Ans...
# 2  2017  B16Jem9xe             Learning in Implicit Generative Models
# 3  2017  B16dGcqlx                    Third Person Imitation Learning
# 4  2017  B184E5qee  Improving Neural Language Models with a Contin...
#
#                                             abstract  \
# 0  A recent approach to few-shot classification c...
# 1  Machine comprehension of text is an important ...
# 2  Generative adversarial networks (GANs) provide...
# 3  Reinforcement learning (RL) makes it possible ...
# 4  We propose an extension to neural network lang...
#
#                                           authors author_ids  \
# 0        Jake Snell, Kevin Swersky, Richard Zemel
# 1                       Shuohang Wang, Jing Jiang
# 2         Shakir Mohamed, Balaji Lakshminarayanan
# 3  Bradly C Stadie, Pieter Abbeel, Ilya Sutskever
# 4   Edouard Grave, Armand Joulin, Nicolas Usunier
#
#                    decision     scores  \
# 0                    Reject  [6, 4, 5]
# 1           Accept (Poster)  [6, 6, 7]
# 2  Invite to Workshop Track  [8, 7, 6]
# 3           Accept (Poster)  [6, 5, 6]
# 4           Accept (Poster)  [7, 9, 5]
#
#                                        keywords             labels
# 0            [deep learning, transfer learning]  transfer learning
# 1  [natural language processing, deep learning]    language models
# 2                       [unsupervised learning]          unlabeled
# 3                                            []          unlabeled
# 4                 [natural language processing]    language models

# %%
df_fromLocal = pd.read_parquet("data/iclr/iclr25v2.parquet")
df_fromLocal.head()
# Out:
#    year         id                                              title  \
# 0  2017  B1-Hhnslg        Prototypical Networks for Few-shot Learning
# 1  2017  B1-q5Pqxl  Machine Comprehension Using Match-LSTM and Ans...
# 2  2017  B16Jem9xe             Learning in Implicit Generative Models
# 3  2017  B16dGcqlx                    Third Person Imitation Learning
# 4  2017  B184E5qee  Improving Neural Language Models with a Contin...
#
#                                             abstract  \
# 0  A recent approach to few-shot classification c...
# 1  Machine comprehension of text is an important ...
# 2  Generative adversarial networks (GANs) provide...
# 3  Reinforcement learning (RL) makes it possible ...
# 4  We propose an extension to neural network lang...
#
#                                           authors author_ids  \
# 0        Jake Snell, Kevin Swersky, Richard Zemel
# 1                       Shuohang Wang, Jing Jiang
# 2         Shakir Mohamed, Balaji Lakshminarayanan
# 3  Bradly C Stadie, Pieter Abbeel, Ilya Sutskever
# 4   Edouard Grave, Armand Joulin, Nicolas Usunier
#
#                    decision     scores  \
# 0                    Reject  [6, 4, 5]
# 1           Accept (Poster)  [6, 6, 7]
# 2  Invite to Workshop Track  [8, 7, 6]
# 3           Accept (Poster)  [6, 5, 6]
# 4           Accept (Poster)  [7, 9, 5]
#
#                                        keywords             labels
# 0            [deep learning, transfer learning]  transfer learning
# 1  [natural language processing, deep learning]    language models
# 2                       [unsupervised learning]          unlabeled
# 3                                            []          unlabeled
# 4                 [natural language processing]    language models

# %%
import os, json
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch

from irm_iclr_high_quality import DataConfig, make_examples, compute_year_stats, z_transform_with_stats
from irm_infer_only import IRMScorer
from irm_iclr import compute_year_stats  # 念のため別行で

# === 設定 ===
model_dir = MODEL_DIR
data_path = "data/iclr/iclr25v2.parquet"
target_type = "year_z"   # or "raw"
accept_threshold = 6.0
add_year_tag = True

use_sliding = True
stride_ratio = 0.75
agg = "median"
use_reward = True
max_len = 512
bs = 64
eval_subset = "valid"   # "train" / "valid"

# === データ再構築（examplesベース） ===
dcfg = DataConfig(
    data_path=data_path,
    model_name="allenai/scibert_scivocab_uncased",
    max_length=max_len,
    seed=123,
    train_ratio=0.9,
    target_type=target_type,
    accept_threshold=accept_threshold,
    add_year_tag=add_year_tag,
)

examples_all = make_examples(dcfg)  # ここには text/score/year/accept が入る（targetはまだ）
n_train = int(len(examples_all) * dcfg.train_ratio)
train_ex  = examples_all[:n_train]
valid_ex  = examples_all[n_train:]

# 学習統計で z を作成（year_z のとき）
if target_type == "year_z":
    year_stats, default_stats = compute_year_stats(train_ex)  # 学習側統計
    train_ex = z_transform_with_stats(train_ex, year_stats, default_stats)
    valid_ex = z_transform_with_stats(valid_ex, year_stats, default_stats)
else:
    for ex in train_ex: ex["target"] = float(ex["score"])
    for ex in valid_ex: ex["target"] = float(ex["score"])

examples = valid_ex if eval_subset == "valid" else train_ex

texts       = [e["text"] for e in examples]
targets     = np.array([e["target"] for e in examples], dtype=float)   # ← もう存在する
scores_raw  = np.array([e["score"]  for e in examples], dtype=float)
years       = np.array([e.get("year", None) for e in examples])
accept_true = (scores_raw >= accept_threshold).astype(int)

# === スコアラ（HFからロード）
scorer = IRMScorer(
    model_dir=model_dir,
    max_length=max_len,
    window_stride_ratio=stride_ratio,
    agg=agg,
)

# === 推論（バッチ）
preds = []
rewards = []
with torch.no_grad():
    for i in tqdm(range(0, len(texts), bs)):
        out = scorer.score_texts(texts[i:i+bs])  # [{'raw_score':..., 'reward':...}]
        preds.extend([d["raw_score"] for d in out])
        rewards.extend([d["reward"] for d in out])

preds   = np.array(preds, dtype=float)
rewards = np.array(rewards, dtype=float)
y_score = rewards if use_reward else preds

print("推論完了:", len(y_score))
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]You're using a DebertaV2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 100%|██████████| 56/56 [01:38<00:00,  1.76s/it]
# 推論完了: 3562

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, precision_score, recall_score

# y_score = rewards か preds は既に定義済み
# accept_true = 0/1 のラベルも既にある

auc = roc_auc_score(accept_true, y_score)
print("AUC =", auc)

# しきい値 0.5 で採択/不採択二値化（reward を使う場合は 0.5 が自然）
pred_accept = (y_score >= 0.5).astype(int)

print("Accuracy =", accuracy_score(accept_true, pred_accept))
print("F1 =", f1_score(accept_true, pred_accept))
print("Precision =", precision_score(accept_true, pred_accept))
print("Recall =", recall_score(accept_true, pred_accept))

from sklearn.metrics import f1_score

best_f1 = -1
best_th = None

for th in np.linspace(0, 1, 200):
    pred = (y_score >= th).astype(int)
    f1 = f1_score(accept_true, pred)
    if f1 > best_f1:
        best_f1 = f1
        best_th = th

print("Best threshold =", best_th)
print("Best F1 =", best_f1)


pred_accept = (y_score >= best_th).astype(int)

print("Accuracy =", accuracy_score(accept_true, pred_accept))
print("F1 =", f1_score(accept_true, pred_accept))
print("Precision =", precision_score(accept_true, pred_accept))
print("Recall =", recall_score(accept_true, pred_accept))
# Out:
# /app/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# AUC = 0.6283970170269545
# Accuracy = 0.6875350926445817
# F1 = 0.0
# Precision = 0.0
# Recall = 0.0
# Best threshold = 0.0
# Best F1 = 0.47614973262032084
# Accuracy = 0.3124649073554183
# F1 = 0.47614973262032084
# Precision = 0.3124649073554183
# Recall = 1.0

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

fpr, tpr, _ = roc_curve(accept_true, y_score)
roc_auc = auc(fpr, tpr)

precision, recall, _ = precision_recall_curve(accept_true, y_score)
pr_auc = average_precision_score(accept_true, y_score)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr, label=f"AUC={roc_auc:.3f}")
plt.plot([0,1],[0,1],'--')
plt.title("ROC Curve")
plt.xlabel("FPR"); plt.ylabel("TPR"); plt.legend()
plt.show()

plt.figure(figsize=(5,5))
plt.plot(recall, precision, label=f"PR-AUC={pr_auc:.3f}")
plt.title("PR Curve")
plt.xlabel("Recall"); plt.ylabel("Precision"); plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(targets, preds, s=6, alpha=0.4)
z = np.polyfit(targets, preds, 1)
xs = np.linspace(targets.min(), targets.max(), 100)
plt.plot(xs, z[0]*xs + z[1], '--')
plt.xlabel("target (year_z or raw)")
plt.ylabel("prediction (logit)")
plt.title("Pred vs Target")
plt.show()

# %%
from scipy.stats import spearmanr
df = pd.DataFrame({"year": years, "pred": preds, "tgt": targets})
per = df.groupby("year").apply(lambda g: spearmanr(g["pred"], g["tgt"]).correlation)

plt.figure(figsize=(7,4))
plt.bar(per.index.astype(str), per.values)
plt.ylim(0, 1)
plt.ylabel("Spearman")
plt.title("Per-Year Spearman")
plt.show()

per
# Out:
# /tmp/ipykernel_1044709/4070593614.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   per = df.groupby("year").apply(lambda g: spearmanr(g["pred"], g["tgt"]).correlation)
# year
# 2025    0.68455
# dtype: float64

# %%
def calibration_bins(y_true_bin, y_score, n_bins=10):
    qs = np.quantile(y_score, np.linspace(0,1,n_bins+1))
    bins = []
    for i in range(n_bins):
        lo, hi = qs[i], qs[i+1]
        sel = (y_score >= lo) & (y_score <= hi if i==n_bins-1 else y_score < hi)
        idx = np.where(sel)[0]
        if len(idx)==0:
            bins.append((lo, hi, 0, np.nan, (lo+hi)/2))
            continue
        bins.append((lo, hi, len(idx), np.mean(y_true_bin[idx]), np.mean(y_score[idx])))
    return bins

bins = calibration_bins(accept_true, y_score)
pred_mean = [b[4] for b in bins]
true_mean = [b[3] for b in bins]

plt.figure(figsize=(5,5))
plt.plot([0,1],[0,1],'--')
plt.plot(pred_mean, true_mean, marker='o')
plt.xlabel("Predicted")
plt.ylabel("Empirical Accept Rate")
plt.title("Reliability (Calibration)")
plt.show()

bins
# Out:
# [(0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.0, 0, nan, 0.0),
#  (0.0, 0.001565804659228298, 3205, 0.25273010920436817, 3.178947757024114e-06),
#  (0.001565804659228298,
#   0.055585522203156476,
#   357,
#   0.8487394957983193,
#   0.01866661477212952)]

# %%
def confusion(th):
    pred = (y_score >= th).astype(int)
    TP = ((pred==1)&(accept_true==1)).sum()
    FP = ((pred==1)&(accept_true==0)).sum()
    TN = ((pred==0)&(accept_true==0)).sum()
    FN = ((pred==0)&(accept_true==1)).sum()
    P = TP / max(TP+FP,1e-9)
    R = TP / max(TP+FN,1e-9)
    F1 = 2*P*R/max(P+R,1e-9)
    return F1, th, TP, FP, TN, FN, P, R

ths = np.unique(y_score)
best = max(confusion(th) for th in ths)
best
# Out:
# (0.4761497326203209, 0.0, 1113, 2449, 0, 0, 0.3124649073554183, 1.0)
